# %%
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline


import random
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import deque

# %%
from dqn_agent import Agent
from env_setup import EnvGrid

env = EnvGrid (8 , 4)
#agent = Agent(state_size=6, action_size=2, seed=0)
agent = Agent(state_size=9, action_size=34, seed=2)

# %%
def dqn(n_episodes=1000000, max_t=1, eps_start=0.0, eps_end=0.0, eps_decay=0.99):
   
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
        
    """
    

    
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        state = env.reset() #note state is atuple with a state and normalized state
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps) #select normalized state
            next_state, reward,done = env.env_behaviour(state, action)
            #if reward == 1:
                #print("reward = 1: state, action:\n", state, "\n", action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 5000 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)),eps)
        
        if i_episode % 1000 == 0:
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            
        if np.mean(scores_window) >=0 and i_episode >= 1000:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            break
            
    return scores

scores = dqn()
# Out:
# Episode 5000	Average Score: -0.53 0.0
# Episode 10000	Average Score: -0.47 0.0
# Episode 15000	Average Score: -0.41 0.0
# Episode 20000	Average Score: -0.29 0.0
# Episode 25000	Average Score: -0.31 0.0
# Episode 30000	Average Score: -0.32 0.0
# Episode 35000	Average Score: -0.27 0.0
# Episode 40000	Average Score: -0.23 0.0
# Episode 45000	Average Score: -0.25 0.0
# Episode 50000	Average Score: -0.23 0.0
# Episode 55000	Average Score: -0.31 0.0
# Episode 60000	Average Score: -0.31 0.0
# Episode 65000	Average Score: -0.18 0.0
# Episode 70000	Average Score: -0.40 0.0
# Episode 75000	Average Score: -0.32 0.0
# Episode 80000	Average Score: -0.34 0.0
# Episode 85000	Average Score: -0.30 0.0
# Episode 90000	Average Score: -0.22 0.0
# Episode 95000	Average Score: -0.32 0.0
# Episode 100000	Average Score: -0.30 0.0
# Episode 105000	Average Score: -0.30 0.0
# Episode 110000	Average Score: -0.38 0.0
# Episode 115000	Average Score: -0.31 0.0
# Episode 120000	Average Score: -0.34 0.0
# Episode 125000	Average Score: -0.33 0.0
# Episode 130000	Average Score: -0.34 0.0
# Episode 135000	Average Score: -0.29 0.0
# Episode 140000	Average Score: -0.30 0.0
# Episode 145000	Average Score: -0.38 0.0
# Episode 150000	Average Score: -0.33 0.0
# Episode 155000	Average Score: -0.30 0.0
# Episode 160000	Average Score: -0.31 0.0
# Episode 165000	Average Score: -0.18 0.0
# Episode 170000	Average Score: -0.35 0.0
# Episode 175000	Average Score: -0.31 0.0
# Episode 180000	Average Score: -0.24 0.0
# Episode 185000	Average Score: -0.28 0.0
# Episode 190000	Average Score: -0.29 0.0
# Episode 195000	Average Score: -0.14 0.0
# Episode 200000	Average Score: -0.23 0.0
# Episode 205000	Average Score: -0.17 0.0
# Episode 210000	Average Score: -0.10 0.0
# Episode 215000	Average Score: -0.34 0.0
# Episode 220000	Average Score: -0.36 0.0
# Episode 225000	Average Score: -0.34 0.0
# Episode 230000	Average Score: -0.18 0.0
# Episode 235000	Average Score: -0.07 0.0
# Episode 240000	Average Score: -0.12 0.0
# Episode 245000	Average Score: -0.15 0.0
# Episode 250000	Average Score: -0.20 0.0
# Episode 255000	Average Score: -0.15 0.0
# Episode 260000	Average Score: -0.18 0.0
# Episode 265000	Average Score: -0.24 0.0
# Episode 270000	Average Score: -0.13 0.0
# Episode 275000	Average Score: -0.10 0.0
# Episode 280000	Average Score: -0.15 0.0
# Episode 285000	Average Score: -0.12 0.0
# Episode 290000	Average Score: -0.09 0.0
# Episode 295000	Average Score: -0.18 0.0
# Episode 300000	Average Score: -0.09 0.0
# Episode 305000	Average Score: -0.13 0.0
# Episode 310000	Average Score: -0.18 0.0
# Episode 315000	Average Score: -0.16 0.0
# Episode 320000	Average Score: -0.11 0.0
# Episode 325000	Average Score: -0.08 0.0
# Episode 330000	Average Score: -0.08 0.0
# Episode 335000	Average Score: -0.15 0.0
# Episode 340000	Average Score: -0.12 0.0
# Episode 345000	Average Score: -0.10 0.0
# Episode 350000	Average Score: -0.03 0.0
# Episode 350039	Average Score: 0.001
# Environment solved in 349939 episodes!	Average Score: 0.00
